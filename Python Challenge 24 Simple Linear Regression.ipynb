# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline

# %%
df = pd.read_csv("dataset.csv")
df = df.drop(columns = ["Unnamed: 3","Unnamed: 4","Unnamed: 5","Unnamed: 6","Unnamed: 7","Unnamed: 8","Unnamed: 9"])
df["Y_test"] = [120000,230000,150000,167000,198000,188000,137000,199000,222000]
df
# Out:
#    X_train  X_test  Y_train  Y_test
# 0      1.2     1.1   150000  120000
# 1      2.3     2.4   200000  230000
# 2      1.5     1.6   180000  150000
# 3      2.7     2.8   210000  167000
# 4      1.8     1.9   170000  198000
# 5      2.5     2.3   190000  188000
# 6      1.7     1.5   175000  137000
# 7      2.4     2.7   200000  199000
# 8      1.9     1.8   185000  222000

# %%
model = LinearRegression()

Xtr = df["X_train"].values.reshape(-1, 1)
Ytr = df["Y_train"].values

Xte = df["X_test"].values.reshape(-1, 1)
Yte = df["Y_test"].values

model.fit(X, Y)
Ytrp = model.predict(Xtr)
Ytep = model.predict(Xte)

# %%
mse_train = mean_squared_error(Ytr, Ytrp)
mse_test = mean_squared_error(Yte, Ytep)
r2_train = r2_score(Ytr, Ytrp)
r2_test = r2_score(Yte, Ytep)

print("Training Mean Squared Error: {}".format(mse_train))
print("Testing Mean Squared Error: {}".format(mse_test))
print("Training R-squared: {}".format(r2_train))
print("Testing R-squared: {}".format(r2_test))
# Out:
# Training Mean Squared Error: 49993888.27771665
# Testing Mean Squared Error: 880831755.7828392
# Training R-squared: 0.8316214157798316
# Testing R-squared: 0.3119696405098462

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

axs[0, 0].scatter(Xtr, Ytr, c='blue')
axs[0, 0].set_title('Xtrain vs Ytrain')
axs[0, 0].set_xlabel('Xtr')
axs[0, 0].set_ylabel('Ytr')

axs[0, 1].scatter(Xte, Yte, c='red')
axs[0, 1].set_title('Xtest vs Ytest')
axs[0, 1].set_xlabel('Xte')
axs[0, 1].set_ylabel('Yte')

axs[1, 0].scatter(Xtr, Ytrp, c='green')
axs[1, 0].set_title('Xtrain vs Ytrainpred')
axs[1, 0].set_xlabel('Xtr')
axs[1, 0].set_ylabel('Ytrp')

axs[1, 1].scatter(Xte, Ytep, c='yellow')
axs[1, 1].set_title('Xtest vs Ytestpred')
axs[1, 1].set_xlabel('Xte')
axs[1, 1].set_ylabel('Ytep')
# Out:
# Text(0, 0.5, 'Ytep')
